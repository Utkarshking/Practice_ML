# %% [markdown]
# 1) Decision Trees is a type heirarchical tree structure which is used to make decision on the basis of some rules which are being stated when building the model
# 2) Sometimes we can land to the leaf nodes when we can find impurities it means we have made a decision for some group but also some other group also lie to the structure for example we have a basketball and a jockey player we have to make a decision that if the weight is more than > 150 lbs then he/she is a basketball player but we can say that there could be a posibility where there could be a jockey player as well which will carry the same rule but also he is jockey player so that can be stated as a impurity
# 3) Impurity can be measured in two different ways Gini Impurity and Entropy
#
# Random forest can be said as it is the collection of all the decision tree models
#
#
# Gradient boosting uses the weaker decision tree models ,train them and then make the next decision tree model , the next decision tree always learns from the previous tree mistakes
#
# many weak learners make a strong model after all that is the target for gradient boosting
#
#
# Model 1:-
#
# y=a1+b1x+e1  (a and b are coeffs and e is the residual)
#
#
# Model 2:-
# e1=a2+b2x+e2
#
# Model 3:-
#
# e2=a3+b3x+e3
#
#
# Combined Model = a1+a2+a3+(b1+b2+b3)x+e3
#
#
# High Shrinkage factor scales down the importance of each learner
#
#
# slows down learning thus reduces overfitting
#
#
# More learners -> shrink a lot
#
# less learners -> Shrink a little
# Typhical Values (0.1,1 )

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
df=pd.read_csv('drug200.csv')



df = pd.get_dummies(df, columns=['Sex'])
df = pd.get_dummies(df, columns=['BP'])
df = pd.get_dummies(df, columns=['Cholesterol'])
df
# Out:
#      Age  Na_to_K   Drug  Sex_F  Sex_M  BP_HIGH  BP_LOW  BP_NORMAL  \
# 0     23   25.355  drugY   True  False     True   False      False
# 1     47   13.093  drugC  False   True    False    True      False
# 2     47   10.114  drugC  False   True    False    True      False
# 3     28    7.798  drugX   True  False    False   False       True
# 4     61   18.043  drugY   True  False    False    True      False
# ..   ...      ...    ...    ...    ...      ...     ...        ...
# 195   56   11.567  drugC   True  False    False    True      False
# 196   16   12.006  drugC  False   True    False    True      False
# 197   52    9.894  drugX  False   True    False   False       True
# 198   23   14.020  drugX  False   True    False   False       True
# 199   40   11.349  drugX   True  False    False    True      False
#
#      Cholesterol_HIGH  Cholesterol_NORMAL
# 0                True               False
# 1                True               False
# ...

# %%
X=df.drop('Drug',axis=1)
Y=df['Drug']

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.5,random_state=20)

# %%
clf=DecisionTreeClassifier()


clf.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=clf.predict(X_test)

# %%
accuracy_score(Y_test,y_pred)
# Out:
# 0.96

# %%
import matplotlib.pyplot as plt


import matplotlib.pyplot as plt

plt.plot(y_pred,label='Predicted')
plt.plot(Y_test,label='Actual')


plt.ylabel('Drug')


plt.legend()


plt.show()
