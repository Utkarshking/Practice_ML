# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.2'

# %%
laptop_data=pd.read_csv("dataset.csv")
laptop_data
# Out:
#      Company                              Product            TypeName  Inches  \
# 0      Apple                          MacBook Pro           Ultrabook    13.3
# 1      Apple                          Macbook Air           Ultrabook    13.3
# 2         HP                               250 G6            Notebook    15.6
# 3      Apple                          MacBook Pro           Ultrabook    15.4
# 4      Apple                          MacBook Pro           Ultrabook    13.3
# ...      ...                                  ...                 ...     ...
# 1270  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1271  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1272  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1273      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1274    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
# ...

# %%
def data_preprocess(data , x):
    temp = pd.get_dummies(data[x],drop_first = True).astype(int)
    data = pd.concat([data,temp],axis =1)
    data = data.drop(columns =x)
    return data
    
df = data_preprocess(laptop_data,'Company')
df =data_preprocess(laptop_data,'TypeName')
df = data_preprocess(laptop_data,'CPU_Company')
df = data_preprocess(laptop_data,'GPU_Company')
df = data_preprocess(laptop_data,'OpSys')
df
# Out:
#      Company                              Product            TypeName  Inches  \
# 0      Apple                          MacBook Pro           Ultrabook    13.3
# 1      Apple                          Macbook Air           Ultrabook    13.3
# 2         HP                               250 G6            Notebook    15.6
# 3      Apple                          MacBook Pro           Ultrabook    15.4
# 4      Apple                          MacBook Pro           Ultrabook    13.3
# ...      ...                                  ...                 ...     ...
# 1270  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1271  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1272  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1273      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1274    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
# ...

# %%
X = df.drop(columns= 'Price (Euro)') # Features
Y = df['Price (Euro)'] # Target column

# %% [markdown]
# Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder


label=LabelEncoder()

for columns in X.select_dtypes('object').columns:
    X[columns]=label.fit_transform(X[columns])

# %% [markdown]
# Numerical Normalisation

# %%
Numerical_columns = df.select_dtypes(exclude = 'object').columns



from sklearn.preprocessing import MinMaxScaler


scaler=MinMaxScaler()


df[Numerical_columns]= scaler.fit_transform(df[Numerical_columns])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split


X_train,X_Test,Y_Train,Y_Test=train_test_split(X,Y,test_size=0.2)

linear_model=LinearRegression()

linear_model.fit(X_train,Y_Train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error,r2_score
Y_Pred = linear_model.predict(X_Test)

MSE = mean_squared_error(Y_Test,Y_Pred)
r2 = r2_score(Y_Test, Y_Pred)

MSE,r2
# Out:
# (160574.31616939715, 0.6204100002484441)

# %%
linear_model.score(X_train,Y_Train)
# Out:
# 0.7226918689846097

# %%
predictors=X_train.columns

coef=pd.Series(linear_model.coef_,predictors).sort_values()


coef
# Out:
# Inches                 -67.743667
# Product                  0.159301
# GPU_Type                 3.596444
# CPU_Type                 5.485117
# Memory                   6.481162
# ScreenResolution         7.074243
# TypeName                14.818672
# Company                 16.191624
# CPU_Company             56.745150
# RAM (GB)                80.196103
# Weight (kg)            105.197229
# No OS                  115.906995
# GPU_Company            135.869363
# CPU_Frequency (GHz)    265.569047
# Linux                  272.497051
# Chrome OS              410.016480
# Windows 10             426.248839
# Windows 10 S           449.539977
# Mac OS X               775.722469
# Windows 7              857.299227
# macOS                  899.478060
# dtype: float64

# %%
import matplotlib.pyplot as plt

plt.plot(Y_Pred,label='Predicted')
plt.plot(Y_Test,label='Actual')


plt.ylabel('Price')


plt.legend()


plt.show()

# %%
from math import sqrt

sqrt(MSE)
# Out:
# 400.7172521484409

# %% [markdown]
# Lasso Regression uses L1 Norm

# %%
from sklearn.linear_model import Lasso

Lasso_model=Lasso(alpha=5)

Lasso_model.fit(X_train,Y_Train)
# Out:
# Lasso(alpha=5)

# %%
Lasso_model.score(X_train,Y_Train)
# Out:
# 0.7113973552757465

# %%
coef=pd.Series(Lasso_model.coef_,predictors).sort_values()
coef
# Out:
# No OS                 -195.034496
# Inches                 -54.074139
# Linux                  -47.949171
# macOS                    0.000000
# Windows 10 S            -0.000000
# CPU_Company              0.000000
# Windows 10               0.000000
# Mac OS X                 0.000000
# Chrome OS               -0.000000
# Product                  0.144334
# GPU_Type                 3.194056
# CPU_Type                 5.435824
# Memory                   5.961604
# ScreenResolution         8.291233
# Company                 13.046568
# TypeName                18.644130
# Weight (kg)             43.608676
# RAM (GB)                85.108835
# GPU_Company            130.880033
# CPU_Frequency (GHz)    244.164338
# Windows 7              280.101474
# dtype: float64

# %%
Y_Pred=Lasso_model.predict(X_Test)
Y_Pred
# Out:
# array([1093.72702231, 1943.06570835,  803.96104488, 1778.25235745,
#        2069.53042729, 3270.8587409 ,  360.07307457, 1017.87206072,
#        1026.4140758 ,  138.83867674,  475.59388247, 2081.45363594,
#        3585.4278593 ,  338.77031928,  675.95203057,  281.96740123,
#        1483.26280078, 1246.38837538,  345.22482549,  717.67079908,
#         586.94461272, 2084.63178553, 1430.86365741,  357.21761187,
#        1279.4554895 ,  939.28439248, 1196.0947472 ,  315.66715818,
#         764.99302783,  639.91974768,  893.22339392, 1863.61564726,
#         265.12118406,  943.96273247,  612.28701519, 1954.27617332,
#         264.65863608, 1056.88401928, 1322.70847324, 1118.53626921,
#        1223.61161931, 1409.73450423,  755.26847503,  447.08818157,
#        1412.09515312, 1009.54038006, 1176.69641073, 2348.55090564,
#         456.60702447,  712.96805905, 1078.8707455 , 1375.02005051,
#         802.44633578, 1099.21034123, 1380.81360977,  809.07417226,
# ...

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']=(15,6)
plt.plot(Y_Pred,label='Predicted')
plt.plot(Y_Test,label='Actual')


plt.ylabel('Price')


plt.legend()


plt.show()

# %%
rsquare=Lasso_model.score(X_Test,Y_Test)

rsquare
# Out:
# 0.5926939602612494

# %% [markdown]
# Ridege Regression uses N2 Norm

# %%
from sklearn.linear_model import Ridge


ridge_model=Ridge(alpha=1.0)


ridge_model.fit(X_train,Y_Train)
# Out:
# Ridge()

# %%
ridge_model.score(X_train,Y_Train)
# Out:
# 0.7219786538217545

# %%
Y_Pred=ridge_model.predict(X_train)

# %%
coef=pd.Series(ridge_model.coef_,predictors).sort_values()

coef
# Out:
# No OS                 -293.046790
# Linux                 -142.316660
# Inches                 -65.993822
# Chrome OS               -0.513201
# Product                  0.151033
# GPU_Type                 3.624931
# CPU_Type                 5.536920
# Memory                   6.240819
# ScreenResolution         7.014267
# Windows 10              11.213868
# Company                 15.776097
# TypeName                17.314751
# Windows 10 S            30.893343
# CPU_Company             56.510568
# RAM (GB)                80.706177
# Weight (kg)            101.203254
# GPU_Company            136.419529
# CPU_Frequency (GHz)    265.694689
# Mac OS X               306.269269
# Windows 7              427.979071
# macOS                  442.713898
# dtype: float64

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']=(15,6)
plt.plot(Y_Pred,label='Predicted')
plt.plot(Y_Test,label='Actual')


plt.ylabel('Price')


plt.legend()


plt.show()

# %% [markdown]
# Support Vector Regression

# %%
from sklearn.svm import SVR

regression_model=SVR(kernel='linear',C=0.5)

regression_model.fit(X_train,Y_Train)
# Out:
# SVR(C=0.5, kernel='linear')

# %%
regression_model.coef_
# Out:
# array([[ 1.01206044e+01,  2.59910268e-01,  6.98301343e+00,
#         -1.88837017e+01,  1.17974223e+01, -3.50000000e+00,
#          5.53391847e+00,  5.89372037e+01,  8.39034771e+01,
#          4.40105460e+00,  2.39947987e+01,  2.47918985e-01,
#          3.21224098e+00, -1.22789453e+00, -1.32274738e+01,
#          3.00000000e+00, -2.05000000e+01,  1.29963109e+01,
#         -4.09425833e-02,  1.40000000e+01,  6.00000000e+00]])

# %%
regression_model.score(X_train,Y_Train)
# Out:
# 0.646746081429527

# %%
Y_Pred=regression_model.predict(X_Test)

# %%
plt.rcParams['figure.figsize']=(15,6)

plt.plot(Y_Pred,label='Price')


plt.plot(Y_Test,label='Actual')

plt.legend()

plt.show()

# %%
regression_model.score(X_Test,Y_Test)
# Out:
# 0.5587039043571949

# %% [markdown]
# Gradient Boosting Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor


params={'n_estimators':500,'max_depth':6,'min_samples_split':2,'learning_rate':0.01,'loss':'squared_error'}

gbr_model=GradientBoostingRegressor(**params)


gbr_model.fit(X_train,Y_Train)
# Out:
# GradientBoostingRegressor(learning_rate=0.01, max_depth=6, n_estimators=500)

# %%
gbr_model.score(X_train,Y_Train)
# Out:
# 0.9769292245287469

# %%
Y_Pred=gbr_model.predict(X_Test)

# %%
plt.rcParams['figure.figsize']=(15,6)

plt.plot(Y_Pred,label='Predicted')

plt.plot(Y_Test.values,label='Actual')

plt.legend()

plt.show()

# %% [markdown]
# Using grid search to find the best possible model

# %%
from sklearn.model_selection import GridSearchCV

num_estimators=[100,200,500]

learn_rates=[0.01,0.02,0.05,0.1]
max_depths=[4,6,8]

param_grid={
    'n_estimators':num_estimators,
    'learning_rate':learn_rates,
    'max_depth':max_depths
}


grid_search=GridSearchCV(GradientBoostingRegressor(min_samples_split=2,loss='squared_error'),param_grid,cv=3,return_train_score=True)


grid_search.fit(X_train,Y_Train)


grid_search.best_params_
# Out:
# {'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 500}

# %%
len(grid_search.cv_results_)
# Out:
# 19

# %%
for i in range(36):
    print('paramater',grid_search.cv_results_['params'][i])
    print('Mean Test Score', grid_search.cv_results_['mean_test_score'][i])
    print('Rank : ',grid_search.cv_results_['rank_test_score'][i])
    print()
# Out:
# paramater {'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 100}
# Mean Test Score 0.6087808516424636
# Rank :  36
#
# paramater {'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 200}
# Mean Test Score 0.7424061707979908
# Rank :  32
#
# paramater {'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 500}
# Mean Test Score 0.8185438652859892
# Rank :  15
#
# paramater {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 100}
# Mean Test Score 0.6589161261172097
# Rank :  35
#
# paramater {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 200}
# Mean Test Score 0.772665564684277
# Rank :  30
#
# paramater {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 500}
# Mean Test Score 0.8198362338393012
# Rank :  14
#
# paramater {'learning_rate': 0.01, 'max_depth': 8, 'n_estimators': 100}
# Mean Test Score 0.6751781422356725
# Rank :  34
#
# paramater {'learning_rate': 0.01, 'max_depth': 8, 'n_estimators': 200}
# Mean Test Score 0.7746737491828363
# Rank :  29
#
# ...

# %%
params={
   'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 500,'loss':'squared_error','min_samples_split':2
}

gbr_model=GradientBoostingRegressor(**params)

gbr_model.fit(X_train,Y_Train)
# Out:
# GradientBoostingRegressor(max_depth=4, n_estimators=500)

# %%
Y_pred=gbr_model.predict(X_Test)

Y_pred
# Out:
# array([1194.91311949, 1930.09734046,  565.2213413 , 1082.49086661,
#        1287.74493937, 2476.76579815,  332.55444134,  912.42906721,
#         719.42546585,  305.38881232,  498.13665354, 1224.52594536,
#        2774.11193409,  427.2679704 ,  614.86676482,  272.03851765,
#        1255.02184435, 1195.57519652,  357.65625846,  789.18459686,
#         240.90116773, 1440.50099048, 1116.63546128,  416.834002  ,
#         825.65323783,  582.97928825, 2112.7604561 ,  333.63401324,
#         999.15500857,  270.35527589, 1117.2691031 , 1988.03720605,
#         294.89033471,  960.00775126,  485.19535182, 1848.95066151,
#         329.68080379, 1123.06734879, 1197.33899858,  879.29470664,
#        1400.54296696, 1667.94546205,  741.45382674,  495.71377981,
#        1527.63897045,  919.6998875 ,  905.14968609, 2858.19355208,
#         538.68845069, 1128.83725056,  735.07336265, 1595.17314694,
#         472.05419037,  795.6061784 , 1368.59919779,  735.03730659,
# ...

# %%
plt.rcParams['figure.figsize']=(15,6)

plt.plot(Y_pred,label='Predicted',color='Green')

plt.plot(X_Test.values,label='Actual',color='Blue')


plt.legend()

plt.show()

# %%
r_square=gbr_model.score(X_Test,Y_Test)
r_square
# Out:
# 0.8580665310754401
